# %%
#pip install --upgrade pyarrow

# %%
import pandas as pd
from pathlib import Path

path = Path("../data/processed/forecasts/2025-10-27/forecasts.parquet")
df = pd.read_parquet(path, engine="pyarrow")

# %%
df.shape
# Out:
# (248, 12)

# %%
df
# Out:
#     entity liquidity_group week_start target_week_start  horizon  \
# 0      057             TRR 2025-10-27        2025-11-03        1
# 1      4B9             TRR 2025-10-27        2025-11-03        1
# 2      86W             TRR 2025-10-27        2025-11-03        1
# 3      97C             TRR 2025-10-27        2025-11-03        1
# 4      97R             TRR 2025-10-27        2025-11-03        1
# ..     ...             ...        ...               ...      ...
# 243    82J             TRR 2025-10-27        2025-11-17        3
# 244   17C7             TRP 2025-10-27        2025-11-24        4
# 245   25A4             TRP 2025-10-27        2025-11-24        4
# 246    82J             TRP 2025-10-27        2025-11-24        4
# 247    82J             TRR 2025-10-27        2025-11-24        4
#
#      actual_value  y_pred_point  y_pred_p10  y_pred_p50  y_pred_p90  \
# 0             NaN  1.269358e+06         NaN         NaN         NaN
# 1             NaN  2.086539e+06         NaN         NaN         NaN
# 2             NaN  2.265274e+07         NaN         NaN         NaN
# 3             NaN  1.115123e+07         NaN         NaN         NaN
# 4             NaN  1.479489e+07         NaN         NaN         NaN
# ..            ...           ...         ...         ...         ...
# 243           NaN  2.712155e+06         NaN         NaN         NaN
# 244           NaN -6.440510e+05         NaN         NaN         NaN
# 245           NaN -2.874903e+06         NaN         NaN         NaN
# 246           NaN -6.906674e+05         NaN         NaN         NaN
# 247           NaN  1.896623e+06         NaN         NaN         NaN
#
#          model_type  is_pass_through
# 0          lightgbm            False
# 1          lightgbm            False
# 2          lightgbm            False
# 3          lightgbm            False
# 4          lightgbm            False
# ..              ...              ...
# 243  lp_passthrough             True
# 244  lp_passthrough             True
# 245  lp_passthrough             True
# 246  lp_passthrough             True
# 247  lp_passthrough             True
#
# [248 rows x 12 columns]

# %%
backtest_path = Path("../data/processed/backtests/2025-04-07/backtest_predictions.parquet")
backtest_df = pd.read_parquet(backtest_path, engine="pyarrow")

# %%
backtest_df.shape
# Out:
# (6928, 12)

# %%
backtest_df
# Out:
#      entity liquidity_group week_start target_week_start  horizon  \
# 0       057             TRR 2025-04-14        2025-04-21        1
# 1       057             TRR 2025-04-21        2025-04-28        1
# 2       057             TRR 2025-04-28        2025-05-05        1
# 3       057             TRR 2025-05-05        2025-05-12        1
# 4       057             TRR 2025-05-12        2025-05-19        1
# ...     ...             ...        ...               ...      ...
# 6923    82J             TRR 2025-09-29        2025-10-27        4
# 6924    82J             TRR 2025-10-06        2025-11-03        4
# 6925    82J             TRR 2025-10-13        2025-11-10        4
# 6926    82J             TRR 2025-10-20        2025-11-17        4
# 6927    82J             TRR 2025-10-27        2025-11-24        4
#
#       actual_value  y_pred_point  y_pred_p10  y_pred_p50  y_pred_p90  \
# 0       1206515.25  9.972631e+05         NaN         NaN         NaN
# 1       1028057.25  1.236846e+06         NaN         NaN         NaN
# 2       1004180.59  1.281201e+06         NaN         NaN         NaN
# 3       1307428.94  1.113013e+06         NaN         NaN         NaN
# 4        671858.35  1.003217e+06         NaN         NaN         NaN
# ...            ...           ...         ...         ...         ...
# 6923    5860156.81  4.931124e+06         NaN         NaN         NaN
# 6924           NaN  1.124774e+06         NaN         NaN         NaN
# 6925           NaN  1.927825e+06         NaN         NaN         NaN
# 6926           NaN  2.795990e+06         NaN         NaN         NaN
# 6927           NaN  1.896623e+06         NaN         NaN         NaN
#
#           model_type  is_pass_through
# 0           lightgbm            False
# 1           lightgbm            False
# 2           lightgbm            False
# 3           lightgbm            False
# 4           lightgbm            False
# ...              ...              ...
# 6923  lp_passthrough             True
# 6924  lp_passthrough             True
# 6925  lp_passthrough             True
# 6926  lp_passthrough             True
# 6927  lp_passthrough             True
#
# [6928 rows x 12 columns]
