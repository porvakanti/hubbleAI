# %%
#pip install --upgrade pyarrow

# %%
import pandas as pd
from pathlib import Path

path = Path("../data/processed/forecasts/2025-12-05/forecasts.parquet")
df = pd.read_parquet(path, engine="pyarrow")

print(df.head())
print(df.columns.tolist())
# Out:
#   entity liquidity_group week_start target_week_start  horizon  y_pred_point  \
# 0    057             TRR 2014-12-29        2015-01-05        1  1.399089e+06
# 1    057             TRR 2015-01-05        2015-01-12        1  1.122619e+06
# 2    057             TRR 2015-01-12        2015-01-19        1  1.841867e+06
# 3    057             TRR 2015-01-19        2015-01-26        1  1.311521e+06
# 4    057             TRR 2015-01-26        2015-02-02        1  1.209428e+06
#
#    y_pred_p10  y_pred_p50  y_pred_p90 model_type  is_pass_through
# 0         NaN         NaN         NaN   lightgbm            False
# 1         NaN         NaN         NaN   lightgbm            False
# 2         NaN         NaN         NaN   lightgbm            False
# 3         NaN         NaN         NaN   lightgbm            False
# 4         NaN         NaN         NaN   lightgbm            False
# ...

# %%
df.shape
# Out:
# (119156, 11)
